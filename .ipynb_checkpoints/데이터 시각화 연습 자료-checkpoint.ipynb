# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
import numpy as np 
# %matplotlib inline
# 시각화 사전 준비
sns.set_context("talk")
sns.set_style("white")

# 한글 사용 준비
f_path = "c:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 데이터 시각화 연습 자료

# %% [markdown]
# - https://colab.research.google.com/drive/1j5oFjDdYNr6m4CeMiVMtPxizcfLDsE_W?usp=sharing#scrollTo=vx57uOfMyfG4

# %%
# generate data: 월평균 주가 

# 월 
m2020 = ["2020-{:02d}".format(i) for i in range(1,13)]
# 삼성전자 월평균 주가
sec = [58842, 58988, 50357, 49086, 49086, 52968, 54828, 57170, 58176, 59787, 63255, 73343]

# 카카오 월평균 주가
kakao = [32640, 35182, 31920, 33615, 45613, 52834, 64459, 74602, 75905, 71392, 72355, 75260]

# LG전자 월평균 주가
lge = [68860, 65820, 52949, 52748, 56216, 65089, 70857, 84090, 89524, 90789, 87202, 99738]

# 현대자동차 월평균 주가
hdm = [119700, 128012,  91800,  93258,  94808, 103291, 111326, 158588, 176226, 173697, 176762, 189095]

#입력 되었는지 확인 
print(" # 2020년 1월 ~ 12월")
print("-                 월:",m2020)
print("-  삼성전자 주가:",sec)
# Out:
#  # 2020년 1월 ~ 12월
# -                 월: ['2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12']
# -  삼성전자 주가: [58842, 58988, 50357, 49086, 49086, 52968, 54828, 57170, 58176, 59787, 63255, 73343]

# %%
# 1. 상태 기반 (state-based)

plt.figure(figsize = [8,5])
plt.plot(m2020,sec,"o-",label = '삼성전자')
plt.plot(m2020,kakao,'o:',label = '카카오')
plt.plot(m2020,lge,"o--",label ='LG전자')
plt.plot(m2020,hdm,'o-.',label='현대차')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
#2. 객체 지향(object-oriented)
fig,ax = plt.subplots(figsize= [8,5])
ax.plot(m2020,sec,"o-",label = '삼성전자')
ax.plot(m2020,kakao,'o:',label = '카카오')
ax.plot(m2020,lge,"o--",label ='LG전자')
ax.plot(m2020,hdm,'o-.',label='현대차')
ax.legend()
ax.set_xticklabels(m2020,rotation=45)
plt.show()
# Out:
# <ipython-input-14-e8ead4285d80>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(m2020,rotation=45)

# %%
# 3. 수익률 비교 
# - 월별 평균 주가 연초 시초가로 나눔
sec_rate = np.array(sec)/sec[0]-1
kakao_rate = np.array(kakao)/kakao[0]-1
lge_rate = np.array(lge)/lge[0]-1
hdm_rate = np.array(hdm)/hdm[0]-1

# %%
fig,ax = plt.subplots(figsize= [8,5])
ax.plot(m2020,sec_rate,label='삼성전자')
ax.plot(m2020,kakao_rate,label='카카오')
ax.plot(m2020,lge_rate,label='LG전자')
ax.plot(m2020,hdm_rate,label='현대자동차')
ax.legend()
ax.set_xticklabels(m2020,rotation=45)
plt.show()
# Out:
# <ipython-input-18-635b378b5c2f>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(m2020,rotation=45)

# %%
# 4. y축 눈금 정비, - 사라짐 문제 해결 
fig,ax = plt.subplots(figsize= [8,5])
ax.plot(m2020,sec_rate,label='삼성전자')
ax.plot(m2020,kakao_rate,label='카카오')
ax.plot(m2020,lge_rate,label='LG전자')
ax.plot(m2020,hdm_rate,label='현대자동차')
ax.legend()
ax.set_xticklabels(m2020,rotation=45)
yticks = np.arange(-0.25,1.75,0.25)
ax.set_yticks(yticks)
ax.set_yticklabels([f"{y*100:.0f}%" for y in yticks])
plt.show()
# Out:
# <ipython-input-19-da85b0f1b3b9>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(m2020,rotation=45)

# %%
# 5. 손익이 잘 드러나게 변경

# 4. y축 눈금 정비, - 사라짐 문제 해결 
fig,ax = plt.subplots(figsize= [8,5])
ax.plot(m2020,sec_rate,label='삼성전자')
ax.plot(m2020,kakao_rate,label='카카오')
ax.plot(m2020,lge_rate,label='LG전자')
ax.plot(m2020,hdm_rate,label='현대자동차')
ax.legend()
ax.set_xticklabels(m2020,rotation=45)
yticks = np.arange(-0.25,1.75,0.25)
ax.set_yticks(yticks)
ax.set_yticklabels([f"{y*100:.0f}%" for y in yticks])
ax.axhline(y=0,c='gray',ls = ":")
plt.show()
# Out:
# <ipython-input-21-8a88885c9fa6>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(m2020,rotation=45)

# %%
# 6. 가로축을 깔끔하게 변경

# 5. 손익이 잘 드러나게 변경

# 4. y축 눈금 정비, - 사라짐 문제 해결 
fig,ax = plt.subplots(figsize= [8,5])
ax.plot(m2020,sec_rate,label='삼성전자')
ax.plot(m2020,kakao_rate,label='카카오')
ax.plot(m2020,lge_rate,label='LG전자')
ax.plot(m2020,hdm_rate,label='현대자동차')
ax.legend()
xticklabels = ["{}월".format(i) for i in range(1,13)]
ax.set_xticks(range(0,12))
ax.set_xticklabels(xticklabels)
# ax.set_xticklabels(m2020,rotation=45)
yticks = np.arange(-0.25,1.75,0.25)
ax.set_yticks(yticks)
ax.set_yticklabels([f"{y*100:.0f}%" for y in yticks])
ax.axhline(y=0,c='gray',ls = ":")
plt.show()

# %%
# y축 grid 추가 
# 6. 가로축을 깔끔하게 변경

# 5. 손익이 잘 드러나게 변경

# 4. y축 눈금 정비, - 사라짐 문제 해결 
fig,ax = plt.subplots(figsize= [8,5])
ax.plot(m2020,sec_rate,label='삼성전자')
ax.plot(m2020,kakao_rate,label='카카오')
ax.plot(m2020,lge_rate,label='LG전자')
ax.plot(m2020,hdm_rate,label='현대자동차')
ax.legend()
xticklabels = ["{}월".format(i) for i in range(1,13)]
ax.set_xticks(range(0,12))
ax.set_xticklabels(xticklabels)
# ax.set_xticklabels(m2020,rotation=45)
yticks = np.arange(-0.25,1.75,0.25)
ax.set_yticks(yticks)
ax.set_yticklabels([f"{y*100:.0f}%" for y in yticks])
ax.axhline(y=0,c='gray',ls = ":")
ax.grid(axis='y',c='lightgray')
plt.show()

# %%
# 8.title 추가
