# %% [markdown]
# # 수능 Trend Visualization 필사
#
# - 본 컨텐츠는 https://jehyunlee.github.io/2020/12/17/Python-DS-48-suneung/ 을 필사한 내용으로 구성되어 있습니다.

# %% [markdown]
# - 수능은 94학번 이후의 대학 진학을 결정하는 시험입니다.
# - 2021학년도 수능을 포함해 여태까지 총 29회의 수능이 있었습니다.
# - 근 30년간 응시생과 점수에 대한 트렌드를 확인해 보겠습니다.

# %% [markdown]
# # 1. 데이터
#
# ## 1.1 데이터 확보
#
# - 수학능력시험 관련 데이터는 [공공데이터 포털](https://www.data.go.kr/data/15001549/fileData.do) 에서 다운받을 수 있습니다.
# - 여러 데이터가 hwp와 csv 형태로 주어집니다.
# - 이를 정리하고, 파이썬에서 활용하기 쉽도록 칼럼명을 영문으로 바꿔야 합니다.

# %% [markdown]
# ## 1.2 데이터 확인
# - 주피터 노트북에서 데이터를 불러옵니다.

# %%
import pandas as pd 

df_sn = pd.read_csv("data/sn_apply.csv")
df_sn.head()
# Out:
#    year  num_total   num_M   num_F  cat_go3  cat_grad  cat_ged  num_test  \
# 0  1994     742668  437465  305203   521806    213459     7403    716326
# 1  1994     750181  444612  305569   496617    243826     9738    726634
# 2  1995     781749  452360  329389   477960    261492    42297    757488
# 3  1996     840661  478707  361954   526833    300482    13346    809867
# 4  1997     824374  472527  351847   545023    268044    11307    795338
#
#    score_avg  score_avg_M  score_avg_F  score_avg_go3  score_avg_grad  \
# 0       49.2         49.7         48.5           49.0            49.6
# 1       44.5         44.6         44.3           45.2            43.2
# 2       49.7         49.7         49.8           51.2            47.8
# 3       46.1         46.0         46.1           47.0            44.4
# 4       42.7         42.4         43.1           43.6            40.8
#
#    score_t50_avg  score_t50_avg_M  score_t50_avg_F  score_t50_avg_go3  \
# ...

# %% [markdown]
# - 데이터가 모두 온전한지도 봅니다.

# %%
df_sn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   year                29 non-null     int64
#  1   num_total           29 non-null     int64
#  2   num_M               29 non-null     int64
#  3   num_F               29 non-null     int64
#  4   cat_go3             29 non-null     int64
#  5   cat_grad            29 non-null     int64
#  6   cat_ged             29 non-null     int64
#  7   num_test            29 non-null     int64
#  8   score_avg           9 non-null      float64
#  9   score_avg_M         9 non-null      float64
#  10  score_avg_F         9 non-null      float64
#  11  score_avg_go3       9 non-null      float64
#  12  score_avg_grad      9 non-null      float64
#  13  score_t50_avg       9 non-null      float64
#  14  score_t50_avg_M     9 non-null      float64
# ...

# %% [markdown]
# - 점수 데이터 부분에 결측치가 상당합니다.
#     - __재학생과 졸업생의 상위 50% 점수는 단 두 건__입니다.
#     - __29번의 수능 중 9번만 점수 데이터가 있습니다.__
#     - 2002학년도부터 총점을 공개하지 않고 표준점수 등으로 변환해서 공개한 결과입니다.
#     - 동일 기준으로 분석하기 어려워 __점수 분석은 94~01까지만__합니다.

# %% [markdown]
# # 2. 데이터 시각화

# %% [markdown]
# ## 2.1 시각화 준비
#
# - matplotlib을 비롯한 라이브러리들을 불러옵니다.
# - 한글을 사용할 것이므로 한글 설정도 합니다.

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc

# 시각화 사전 준비
sns.set_context("talk")
sns.set_style("white")

# 한글 사용 준비
f_path = "c:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 2.2 시각화 색상 선정
#
# - matplotlib과 seaborn 말고 다른 색을 사용해 봅시다.
# - 인터넷은 넓고 좋은 그림은 많습니다.
# - 논문그림과 구글링 결과 중 일부를 가져옵니다.

# %%
# 이미지 가져오기 
ex0 = plt.imread('./img/img3.png')
ex1 = plt.imread("./img/img4.png")

fig,axs = plt.subplots(ncols=2,figsize=[20,10])

for i, (ax,ex) in enumerate(zip(axs,[ex0,ex1])):
    ax.imshow(ex)
    ax.grid()
fig.tight_layout()

# %% [markdown]
# - 남성과 여성, 그리고 지원자와 응시자를 뽑을 색상을 고릅니다.
# - 색상을 뽑을 자리에 원을 그려서 표시합니다.

# %%
from matplotlib.patches import Circle
